# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style = "darkgrid")
x = np.array([1,2,3,4,54,5,4,3,5,6,4,7,5,3,5,43,3,4,5,4,43,4,5,4,33,])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
