# %%
import matplotlib.pyplot as plt

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

# %%
plt.bar(years, runs)
plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Performance")
# Out:
# Text(0.5, 1.0, 'Performance')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
rohit = [0, 200, 200, 600, 1100, 1200, 1300, 1800, 2200, 2600]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
x = np.arange(len(years))
width = 0.25

# %%
plt.bar(x - width, kohli, width=width, label="Virat Kohli")
plt.bar(x, rohit, width=width, label="Rohit Sharma")
plt.bar(x + width, sehwag, width=width, label="Virender Sehwag")
plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Performance Comparision")
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x24be617b410>,
#   <matplotlib.axis.XTick at 0x24be617baa0>,
#   <matplotlib.axis.XTick at 0x24be5e59f70>,
#   <matplotlib.axis.XTick at 0x24be61eee40>,
#   <matplotlib.axis.XTick at 0x24be61ef710>,
#   <matplotlib.axis.XTick at 0x24be61efcb0>,
#   <matplotlib.axis.XTick at 0x24be61eeff0>,
#   <matplotlib.axis.XTick at 0x24be621cad0>,
#   <matplotlib.axis.XTick at 0x24be621d430>,
#   <matplotlib.axis.XTick at 0x24be621dca0>],
#  [Text(0, 0, '1990'),
#   Text(1, 0, '1992'),
#   Text(2, 0, '1994'),
#   Text(3, 0, '1996'),
#   Text(4, 0, '1998'),
#   Text(5, 0, '2000'),
#   Text(6, 0, '2003'),
#   Text(7, 0, '2005'),
#   Text(8, 0, '2007'),
#   Text(9, 0, '2010')])

# %%
players = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs_5yrs = [500+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1100, 300+600+800+1100+900]

# %%
plt.barh(players, runs_5yrs, color="skyblue")
plt.xlabel("Total Runs in First 5 Years")
plt.title("First 5-Year Performance of Indian Batsmen")
plt.tight_layout()
plt.show()
